# %%
student_name= input("Enter Your Name:")
math= int(input("Enter The mark of math:"))          
science=int(input("Enter The mark of science:"))
english=int(input("Enter The mark of english:"))
computer=int(input("Enter The mark of computer:"))
total_mark= math+science+english+computer
average_mark=(math+science+english+computer)/4
print(student_name)
print("The total mark is:",total_mark)
print("The average mark is:", average_mark)
# Out:
# Enter Your Name:Menna
# Enter The mark of math:99
# Enter The mark of science:98
# Enter The mark of english:100
# Enter The mark of computer:100
# Menna
# The total mark is: 397
# The average mark is: 99.25
